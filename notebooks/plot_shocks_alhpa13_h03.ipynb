# %%
import os
os.chdir("..")

from load.helpers import parse_yaml
from graph.plot_helpers import load_simulation_for_all_sectors
from graph.plotting import plot_defaults, plot_cummulative_defaults, plot_effect_on_sectors_from_other_sectors, plot_pairwise_effect

config_dict = parse_yaml("config.yaml")

# %% [markdown]
# ## Sector level analysis

# %% [markdown]
# ## Model
# parameters:
# - distribution: pareto
# - alpha: 1.3
# - scale parameter: 0.1
# - default threshold: 0.3 (if a firm loses 70% of their equity, they default)
# - number of simulations: 1000
# (results are up to date)

# %%
sectors_dict = load_simulation_for_all_sectors(config_dict["outputs"]["simulations"], "2022_10_31_192529", config_dict["lists"]["sectors"])

# %%
fig = plot_defaults(sectors_dict, "all", 'rounds')

# %%
fig = plot_cummulative_defaults(sectors_dict)

# %%
fig.savefig(f"{config_dict['outputs']['plots']}cummdef_lambda13_h03.png", bbox_inches='tight',dpi=600)

# %%
fig = plot_pairwise_effect(sectors_dict, include_self=False)

# %%
fig.savefig(f"{config_dict['outputs']['plots']}heatmap_lambda13_h03.png", bbox_inches='tight',dpi=600)

# %%
fig = plot_defaults(sectors_dict, "all", 'sectors_total')

# %%
fig = plot_defaults(sectors_dict, "Information Technology", 'sectors_total')

# %%
fig.savefig(f"{config_dict['outputs']['plots']}boxplot_IT_lambda13_h03.png", bbox_inches='tight',dpi=600)

# %%
fig = plot_defaults(sectors_dict, "Health Care", 'sectors_total')

# %%
fig.savefig(f"{config_dict['outputs']['plots']}boxplot_HC_lambda13_h03.png", bbox_inches='tight',dpi=600)

# %%
fig = plot_defaults(sectors_dict, "Consumer Discretionary", 'sectors_total')

# %%
fig.savefig(f"{config_dict['outputs']['plots']}boxplot_CD_lambda13_h03.png", bbox_inches='tight',dpi=600)

# %%
fig = plot_defaults(sectors_dict, "all", 'sectors_direct')

# %%
fig = plot_effect_on_sectors_from_other_sectors(sectors_dict)
